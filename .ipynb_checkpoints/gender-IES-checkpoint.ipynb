# %% [markdown]
# # Universidade Federal do Rio Grande do Norte
# ## Programa de Pós-graduação em Engenharia Elétrica e de Computação
# ### Course: Tópicos Especiais C - Data Science Foundation
# ### Professor: Ivanovitch Silva
# ### Students:
#
# * Aguinaldo Bezerra Batista Júnior
# * Pedro Klisley Ferreira da Silva
# * Ycaro Ravel Dantas
#
# #### Activity: Project 4
# #### Subject: IES employees gender analysis
# #### Objectives: Analyze gender in IES employees from webscrapped data of Portal da Transparência
# #### Base dataset: number_of_employees.csv

# %% [markdown]
# ### 0 Loading Libraries and base dataset

# %%
# Loading needed libraries
import pandas as pd
import requests as requests
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %% [markdown]
# This activity starts with loading a base dataset obtained in professor's guiding notebook. This dataset was built on webscrapped data from [Portal da Transparência](http://www.portaldatransparencia.gov.br/).

# %%
# Loading data retrieved in the professor's guiding notebook
#ies_df = pd.read_csv('number_of_employees.csv', index_col=False)

# %% [markdown]
# In this initial webscrapping process, data was obtained from the [Ministry of Education](http://www.portaldatransparencia.gov.br/servidores//OrgaoExercicio-ListaOrgaos.asp?CodOS=15000) page in [Portal da Transparência](http://www.portaldatransparencia.gov.br/). In this activity we have to go deeper in the webscrapping proccess and obtain more data from several pages in that website.

# %% [markdown]
# ### 1 Retrieving public employee data
# The webscrapping process starts with the analysis of [Portal da Transparência](http://www.portaldatransparencia.gov.br/) webpage structure:
# * Ministry of Education
#     - IES employees pages

# %%
def get_ies():
    #import requests as requests
    rh_codes = []
    names = []
    number_of_employees = []

    start_url = 'http://www.portaltransparencia.gov.br/servidores/OrgaoExercicio-ListaOrgaos.asp?CodOS=15000'
    response = requests.get(start_url)
    start_html = BeautifulSoup(response.text, 'html.parser')
    npages = start_html.find('p', class_='paginaAtual').text.rsplit('/',1)[1]
    
    for page in range(1,int(npages)+1):
    
        page_url = 'http://www.portaltransparencia.gov.br/servidores/\
        OrgaoExercicio-ListaOrgaos.asp?CodOS=15000&Pagina={}'.format(page).replace(" ", "")

        # Make a get request
        response = requests.get(page_url)

        # Pause the loop
        sleep(randint(5,10))
        
        page_html = BeautifulSoup(response.text, 'html.parser')
        
        # Monitor the requests
        #requests += 1
        # elapsed_time = time() - start_time
       # print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
        #clear_output(wait = True)

        # Throw a warning for non-200 status codes
        #if response.status_code != 200:
        #    warn('Request: {}; Status code: {}'.format(requests, response.status_code))

        # Break the loop if the number of requests is greater than expected
        # if requests > 72:
        #     warn('Number of requests was greater than expected.')  
        #    break 

        # information about IES is within a table element
        unit_table = page_html.find_all('table')

        # the second one is the target
        unit_rows  = unit_table[1].find_all('tr')
        unit_rows = unit_rows[1:]

        # Extract data from individual ies rows
        for row in unit_rows:

            # rh codes
            codes = row.find('td', class_ = 'firstChild').text
            rh_codes.append(codes)

            # ies names
            name = row.find('a').text
            names.append(name)

            # number of employees
            employees = row.find('td', attrs = {'style':'text-align: right;'}).text
            number_of_employees.append(int(employees))
            
    
    ies_df = pd.DataFrame({'Code': rh_codes,
                       'IES_name': names,
                       'Number_employees': number_of_employees})
    return ies_df

# %%
ies_df = get_ies()

# %%
ies_df
ies_df.to_csv('ies_df.csv')

# %% [markdown]
# Each IES may have several pages listing employees, so we must access all of them to get the desired data

# %%
# Base URL to access the institutions's list of employees
base_url = 'http://www.portaltransparencia.gov.br/servidores/OrgaoExercicio-ListaServidores.asp?CodOrg={}'

# %%
ies_names = []
names = []
# Base page lookup
#for ies in ies_df.Code:
for ies in ies_df.Code.sort_values().tail(10):
       
    url = base_url.format(ies).replace(" ", "")
    
    # Retrieving content for the main page for the institution
    response = requests.get(url)
    
    # Pause the loop
    sleep(randint(5,10))
    
    # Parsing content
    ies_html = BeautifulSoup(response.text, 'html.parser')
    
    # Discovering the number of pages per institution
    npages = 1
    #npages = ies_html.find('p', class_='paginaAtual').text.rsplit('/',1)[1]
    
    ies_name = ies_html.find_all('td',class_='colunaValor')[1].text.strip()    
    
    # Gathering data from IES employee pages
    for page in range(1,int(npages)+1):
        
        page_url = url+'&Pagina={}'.format(page).replace(" ", "")
        
        resp = requests.get(page_url)
        
         # Pause the loop
        sleep(randint(5,10))
        
        # Retrieving content for the page
        page_html = BeautifulSoup(resp.text, 'html.parser')
        
        page_table_rows = page_html.find_all('td')
            
        # Getting names in each page
        #for row in page_table_rows:
        for row in page_table_rows[:15]:
            name = row.find('a')
            
            if name is not None:
                name = name.text.strip()
                names.append(name)
                ies_names.append(ies_name)

# %% [markdown]
# Now, with scrapped data in hands, a new dataframe can be built. The absent gender information problem will be addressed in next section

# %%
# Building a new dataset based on the lists built from webscrapying
columns = ['Name','IES','Guessed_Gender']
ies_employees_df = pd.DataFrame(columns=columns)
ies_employees_df.Name = names
ies_employees_df.IES = ies_names
ies_employees_df.Guessed_Sex = None

# %%
ies_employees_df
# Out:
#                              Name                                     IES  \
# 0        ABADIA DE FATIMA RESENDE   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 1     ADAILTON JOSE ALVES DA CRUZ   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 2             ADAIR JOSE DA SILVA   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 3          ADAIR VIEIRA GONCALVES   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 4        ABADIA DE FATIMA RESENDE   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 5     ADAILTON JOSE ALVES DA CRUZ   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 6             ADAIR JOSE DA SILVA   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 7          ADAIR VIEIRA GONCALVES   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 8        ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 9       ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 10  ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 11           ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 12       ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 13      ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 14  ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 15           ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 16       ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 17      ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 18  ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 19           ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 20       ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 21      ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 22  ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 23           ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 24       ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 25      ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 26  ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 27           ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 28       ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 29      ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 30  ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 31           ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 32       ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 33      ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 34  ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 35           ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 36       ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 37      ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 38  ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 39           ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
#
#    Guessed_Gender
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN

# %%
ies_df.Code.sort_values().tail(10)
# Out:
# 80     26350
# 110    26350
# 3      26443
# 48     26443
# 78     26443
# 93     26443
# 33     26443
# 18     26443
# 108    26443
# 63     26443
# Name: Code, dtype: int64

# %% [markdown]
# ### 2 Guessing Genders
# Generally, person's first name is closed related to gender. So, it may be possible to guess gender from a person's firts name using some libraries and APIs.

# %% [markdown]
# Our first approach is to use the [GenderBR](http://fmeireles.com/blog/rstats/genderbr-predizer-sexo) package availabe in R (CRAN) to try to predict gender from a person's first name. We have chosen this package because it bases its prediction on IBGE official data. So, clearly it is an accurate and offline approach to guess gender for brazilian names.

# %%
# We are able to run R commands in ipython using this python library
import rpy2.robjects as robjects
# %load_ext rpy2.ipython

# %%
# %%R
# # Need to load this R library for gender guessing
# suppressMessages(library(genderBR))

# %%
genders = []
# Using robjects to run R procedures
for name in ies_employees_df.Name:
        name = name.split()[0]
        gender = robjects.r.get_gender(name, threshold = 0.95)
        gender = gender.r_repr()
        gender = gender.strip('\"')
        if gender.startswith('NA'):
            gender = None
        genders.append(gender)

# %%
ies_employees_df.Guessed_Gender = genders

# %%
ies_employees_df
# Out:
#                                  Name                                     IES  \
# 0            ABADIA DE FATIMA RESENDE   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 1         ADAILTON JOSE ALVES DA CRUZ   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 2                 ADAIR JOSE DA SILVA   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 3              ADAIR VIEIRA GONCALVES   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 4   ADALBERTO VITAL DOS SANTOS JUNIOR   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 5            ABADIA DE FATIMA RESENDE   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 6         ADAILTON JOSE ALVES DA CRUZ   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 7                 ADAIR JOSE DA SILVA   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 8              ADAIR VIEIRA GONCALVES   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 9   ADALBERTO VITAL DOS SANTOS JUNIOR   FUND. UNIV FEDERAL DA GRANDE DOURADOS
# 10           ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 11          ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 12      ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 13               ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 14         ABEL BRASIL RAMOS DA SILVA  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 15           ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 16          ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 17      ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 18               ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 19         ABEL BRASIL RAMOS DA SILVA  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 20           ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 21          ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 22      ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 23               ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 24         ABEL BRASIL RAMOS DA SILVA  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 25           ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 26          ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 27      ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 28               ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 29         ABEL BRASIL RAMOS DA SILVA  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 30           ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 31          ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 32      ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 33               ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 34         ABEL BRASIL RAMOS DA SILVA  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 35           ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 36          ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 37      ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 38               ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 39         ABEL BRASIL RAMOS DA SILVA  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 40           ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 41          ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 42      ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 43               ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 44         ABEL BRASIL RAMOS DA SILVA  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 45           ABADIANA FERREIRA MATIAS  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 46          ABBY RENE ARAGONES JUNIOR  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 47      ABDIAS BAPTISTA DE MELLO NETO  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 48               ABDIEL DE LIRA ROLIM  EMPRESA BRAS. DE SERVICOS HOSPITALARES
# 49         ABEL BRASIL RAMOS DA SILVA  EMPRESA BRAS. DE SERVICOS HOSPITALARES
#
#    Guessed_Gender
# 0          Female
# 1            Male
# 2            None
# 3            None
# 4            Male
# 5          Female
# 6            Male
# 7            None
# 8            None
# 9            Male
# 10           None
# 11           None
# 12           Male
# 13           Male
# 14           Male
# 15           None
# 16           None
# 17           Male
# 18           Male
# 19           Male
# 20           None
# 21           None
# 22           Male
# 23           Male
# 24           Male
# 25           None
# 26           None
# 27           Male
# 28           Male
# 29           Male
# 30           None
# 31           None
# 32           Male
# 33           Male
# 34           Male
# 35           None
# 36           None
# 37           Male
# 38           Male
# 39           Male
# 40           None
# 41           None
# 42           Male
# 43           Male
# 44           Male
# 45           None
# 46           None
# 47           Male
# 48           Male
# 49           Male

# %% [markdown]
# R's [GenderBR](http://fmeireles.com/blog/rstats/genderbr-predizer-sexo) did a very good job in gender guessing, however it failed to predict gender for some names. So, a next plausible approach is to use some online API. We have found that the free [Genderize.io](https://genderize.io) dabase contains thousands of distinct names across several countries and languages. This API is keyless but limited to generous 1000 names/day.

# %%
# No API key required for genderize.io
def genderize_io(genderless_name):
    genderless_name = genderless_name.split()[0]
    api_url='https://api.genderize.io/?name={}'.format(genderless_name).replace(" ", "")
    gender = requests.get(api_url,timeout=10).json().get('gender')
    if(gender):
        return gender.capitalize()
    else:
        return None

# %%
for index,row in ies_employees_df.iterrows():
    if row[2] is None:
        gen = genderize_io(row[1])
        if(gen):
            ies_employees_df.Guessed_Gender.loc[index] = gen

# %%
ies_employees_df
# Out:
#                                    Name  \
# 0                 ABELARDO BENTO ARAUJO
# 1                 ABNER BRAGANCA GOUVEA
# 2      ACCACIO FERREIRA DOS SANTOS NETO
# 3                ADALBERTO JOSE DE LIMA
# 4            ADALBERTO PEREIRA DA SILVA
# 5   ADALBERTO TEIXEIRA DE ANDRADE ROCHA
# 6                 ADALTON MARTINS GOMES
# 7                ADELSON DE PAULA SILVA
# 8             ADELSON FERNANDES MOREIRA
# 9               ADERCI DE FREITAS FILHO
# 10               ADILSON MENDES RICARDO
# 11               ADILSON RAMOS DA SILVA
# 12                 ADILSON RANGEL ALVES
# 13              ADILSON SILVEIRA COELHO
# 14              ADIMILSON DE ASSIS CRUZ
#
#                                        IES Guessed_Gender
# 0   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 1   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 2   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 3   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 4   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 5   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 6   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 7   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 8   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 9   CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 10  CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 11  CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 12  CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 13  CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male
# 14  CENTRO FED.DE EDUC.TECNOL.MINAS GERAIS           Male

# %% [markdown]
# ### 3 Gender Analysis in IES

# %%
ies_employees_df.Guessed_Gender.value_counts()
# Out:
# Male    15
# Name: Guessed_Gender, dtype: int64

# %%
# %matplotlib inline
ies_employees_df.Guessed_Gender.value_counts().plot(kind='pie')
